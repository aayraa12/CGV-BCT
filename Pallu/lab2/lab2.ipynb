# %%
from DDA import *

def draw_rectangle(x1, y1, x2, y2):

    x3, y3 = x1, y2
    x4, y4 = x2, y1

    plotDDA(x1, y1, x3, y3)  # Left vertical
    plotDDA(x3, y3, x2, y2)  # Top horizontal
    plotDDA(x2, y2, x4, y4)  # Right vertical
    plotDDA(x4, y4, x1, y1)  # Bottom horizontal

    plt.title("Rectangle Using DDA Algorithm")
   

draw_rectangle(4, 3, 20, 15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#      11     plotDDA(x4, y4, x1, y1)  # Bottom horizontal
#      13     plt.title("Rectangle Using DDA Algorithm")
# ---> 16 draw_rectangle(4, 3, 20, 15)
#
# Cell In[1], line 8, in draw_rectangle(x1, y1, x2, y2)
#       5 x3, y3 = x1, y2
#       6 x4, y4 = x2, y1
# ----> 8 plotDDA(x1, y1, x3, y3)  # Left vertical
#       9 plotDDA(x3, y3, x2, y2)  # Top horizontal
#      10 plotDDA(x2, y2, x4, y4)  # Right vertical
#
# NameError: name 'plotDDA' is not defined

# %%
from DDA import *

def draw_axes(length=20):
    plt.figure(figsize=(6, 6))
    
    # X-axis (horizontal)
    plotDDA(-length, 0, length, 0)
    # Y-axis (vertical)
    plotDDA(0, -length, 0, length)
    
    plt.title("Simple Coordinate System using DDA")
    plt.axis('equal')
    plt.savefig("LAB2_qn2.png", dpi=300, bbox_inches='tight')
    plt.close()

draw_axes(20) # axis of length 20
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 16
#      13     plt.savefig("LAB2_qn2.png", dpi=300, bbox_inches='tight')
#      14     plt.close()
# ---> 16 draw_axes(20) # axis of length 20
#
# Cell In[2], line 4, in draw_axes(length)
#       3 def draw_axes(length=20):
# ----> 4     plt.figure(figsize=(6, 6))
#       6     # X-axis (horizontal)
#       7     plotDDA(-length, 0, length, 0)
#
# NameError: name 'plt' is not defined
